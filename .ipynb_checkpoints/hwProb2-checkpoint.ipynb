# %% [markdown]
# ![Screen Shot 2022-05-19 at 7.27.06 PM.png](attachment:0cb83914-1af5-4c6e-8a12-3df2b9886fec.png)

# %%
import numpy as np

# %%
def idk(x):
    a = 2**-22
    b = a**1-41
    c = b**x/10
    return c

# %%
# x = 192
x = 191
idk(x)
# Out:
# -1.1008195938398734e+307
