# %% [markdown]
# # NN From Scratch
# 1. P. 33 in Ch. 2
# 2. get layer output

# %% [markdown]
# ![nnEx.png](attachment:nnEx.png)

# %%
#process above
inputs = [1, 2, 3, 2.5, 1]
weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87],
           [-0.26, -0.27, 0.17, 0.87],
          ]
biases = [2, 3, 0.5, 2]

#output of current layer
layer_outputs = []

# for each neuron
for neuron_weights, neuron_bias in zip(weights, biases) :
    neuron_output = 0
    
#     for each input & weight to the neuron
    for n_input, weight in zip(inputs, neuron_weights) :
        neuron_output = neuron_output + (n_input * weight)
    
    neuron_output = neuron_output + neuron_bias
    layer_outputs.append(neuron_output)

print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385, 3.885]
