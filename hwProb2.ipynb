# %% [markdown]
# ![Screen Shot 2022-05-19 at 7.27.06 PM.png](attachment:0cb83914-1af5-4c6e-8a12-3df2b9886fec.png)

# %%
import numpy as np

# %%
d = [] 
def idk(x):
    print(x)
 
    # for i in range(len(d)):
    #     print(d[i])
    a = 2**-22
    print("a : ", a)
    b = a**1-41
    print("b : ", b)
        
    cc = np.divide(x, 10)
    c = b**(cc)
    
    return c

# %%
# x = 192
x = 1
# No of Data points
N = 5

# initializing random values
data = np.random.randn(N)
# print(data)
# for i in range(len(data)):
#     idk(data[i])
idk(cdf)
# Out:
# [0.014 0.06  0.164 0.336 0.526 0.772 0.892 0.956 0.992 1.   ]
# a :  2.384185791015625e-07
# b :  -40.99999976158142
# /Users/brinkley97/opt/anaconda3/envs/time_series_basics/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in power
#   del sys.path[0]
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
# defining the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# No of Data points
N = 500

# initializing random values
data = np.random.randn(N)

# getting data of the histogram
count, bins_count = np.histogram(data, bins=10)

# finding the PDF of the histogram using count values
pdf = count / sum(count)

# using numpy np.cumsum to calculate the CDF
# We can also find using the PDF values by looping and adding
cdf = np.cumsum(pdf)
print("cdf : ", cdf)

# plotting PDF and CDF
plt.plot(bins_count[1:], pdf, color="red", label="PDF")
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()
# Out:
# cdf :  [0.014 0.06  0.164 0.336 0.526 0.772 0.892 0.956 0.992 1.   ]
