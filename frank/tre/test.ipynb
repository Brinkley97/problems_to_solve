# %%
import re

# %%
txt = "x3021R"
listTxt = list(txt)
print(listTxt)

# %%
listCount = 0

for listCount in range(1, len(listTxt)):
    print("Index ", listCount, " = ", listTxt[listCount])

# %%
column = [1, 2, 2]
print(column)

# %%
countColumn = 0
for countColumn in range(0, len(column)):
    print("Column count = ", countColumn, "Columm = ", column[countColumn])

# %%
columns = 0
while columns < 42: 
    columns = columns + 1
    print(columns)
    txt = "3021R000101"
    listTxt = list(txt)
#     print("listTxt = ", listTxt)

    digits = [1, 2, 2, 6]
    digit = 0


    for columns in range(0, len(digits)):
        print("Digit = ", digits[columns])

#         listCount = 0

#         for listCount in range(1, len(listTxt)):
    #         print("Column count = ", digits[digit], listTxt[listCount])
    #         print("Column count = ", digits[digit], listTxt[1:2])


#             if digits[digit] == 1:
#                 print("Digit", digits[digit], " = ", listTxt[0:1])     
#             if digits[digit] == 2:
#                 print("Digit", digits[digit], " = ", listTxt[1:3])
#                 break
#             if digits[digit] == 2:
#                 print("Digit", digits[digit], " = ", listTxt[3:5])
#             if digits[digit] == 6:
#                 print("Digit", digits[digit], " = ", listTxt[5:11])
#                 break
# Out:
# 1
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# Digit =  6
# 4
# Digit =  1
# Digit =  2
# Digit =  2
# ...
